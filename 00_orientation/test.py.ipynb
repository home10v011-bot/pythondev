# %%
age = int(input("年齢を入力してください: "))

if(age >= 18) and (age <= 65):
    print("どうぞお乗りください")

print("処理を終了します")
# Out:
# 処理を終了します

# %%
age = int(input("年齢を入力してください: "))

if age >= 18:
    if age <= 65:
        print("どうぞお乗りください")
    
print("処理を終了します")
# Out:
# どうぞお乗りください
# 処理を終了します

# %%
score = int(input("点数を入力してください"))

if score >= 90:
    print("優秀です")
    print("大変よくできました！")

elif score >= 60:
    print("合格です")
    print("おめでとうございます！")

else:
    print("不合格です")
    print("もっとがんばりましょう")

print("処理を修正します")
# Out:
# 優秀です
# 大変よくできました！
# 処理を修正します

# %%
season = input("季節を入力してください")

match season:
    case "春":
        print("春はあけぼの")
    case "夏":
        print("夏は夜")
    case "秋":
        print("秋は夕暮れ")
    case "冬":
        print("冬はつとめて")
    case _:
        print("エラー")

print("処理を終了します")
# Out:
# エラー
# 処理を終了します

# %%
score = int(input("点数を入力してください: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 score = int(input("点数を入力してください: "))
#
# ValueError: invalid literal for int() with base 10: 'あいうえお'

# %%
try:
    score = int(input("点数を入力してください: "))
except ValueError:
    print("エラー: 数値を入力してください")
except:
    print("エラー: 何らかのエラーが発生しました")
else:
    if score >= 60:
        print("合格です")
        print("おめでとうございます！")
finally:
    print("処理を終了します")
# Out:
# エラー: 数値を入力してください
# 処理を終了します

# %%
station1 = "東京"
station2 = "新橋"
price = 140
f"{station1}から{station2}までの運賃は{price}円です。"
# Out:
# '東京から新橋までの運賃は140円です。'

# %%
print(f"{station1=} {station2=} {price=}")
# Out:
# station1='東京' station2='新橋' price=140

# %%
station1 = "東京"
station2 = "新橋"

budget = 100   # 手持ち予算
price = 140  # 運賃

# %%
price < budget
# Out:
# False

# %%
assert price < budget
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 assert price < budget
#
# AssertionError:

# %%
assert  price < budget, f'手持ちが{budget}円しかないので、その電車には乗れません。'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 assert  price < budget, f'手持ちが{budget}円しかないので、その電車には乗れません。'
#
# AssertionError: 手持ちが100円しかないので、その電車には乗れません。

# %%
budget = 100
price = 1000

if price <= 100:
    print("電車に乗れます")
else:
    raise ValueError(f"{budget}円しかないので、その電車に乗れません。")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       5     print("電車に乗れます")
#       6 else:
# ----> 7     raise ValueError(f"{budget}円しかないので、その電車に乗れません。")
#
# ValueError: 100円しかないので、その電車に乗れません。
