# %%
count = 0
scoretotal = 0

while True:
    score = int(input("点数を入力してください:"))

    if score == -1:
        break

    scoretotal += score
    count += 1
    average = scoretotal / count

print(f"{count}人のテストの平均点は{average}点です")
# Out:
# 10人のテストの平均点は73.4点です
