# %%
price_extax = input("税抜価格を入力してください：")
price_withtax = round(int(price_extax) * 1.1)
price_withtax_350 = price_withtax + 350

print(price_extax)

if price_withtax >= 2000:
    print("送料は無料です")
    print(f"送料込みの価格は{price_withtax}円です。")

else:
    print("送料として350円かかります")
    print(f"送料込みの価格は{price_withtax_350}円です。")
# Out:
# 1800
# 送料として350円かかります
# 送料込みの価格は2330円です。
