# %%
alphabet_list = []
alphabet_dict = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 alphabet_list = []
# ----> 2 alphabet_dict = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
#
# TypeError: 'list' object is not callable
